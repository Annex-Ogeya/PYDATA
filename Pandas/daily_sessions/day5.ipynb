# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\train.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.nunique()
# Out:
# Row ID           9800
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              49
# Postal Code       626
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
data.groupby('Ship Mode')['Sales'].sum()
# Out:
# Ship Mode
# First Class       3.455723e+05
# Same Day          1.252190e+05
# Second Class      4.499142e+05
# Standard Class    1.340831e+06
# Name: Sales, dtype: float64

# %%
data.groupby('Ship Mode')['Sales'].mean()
# Out:
# Ship Mode
# First Class       230.228020
# Same Day          232.749143
# Second Class      236.547939
# Standard Class    228.849856
# Name: Sales, dtype: float64

# %%
data.groupby('Ship Mode')['Sub-Category'].count()
# Out:
# Ship Mode
# First Class       1501
# Same Day           538
# Second Class      1902
# Standard Class    5859
# Name: Sub-Category, dtype: int64

# %%
# add more aggregate columns
data.groupby('Ship Mode').agg({
    "Sales":"sum",
    "Sub-Category":"count"
}).reset_index()
# Out:
#         Ship Mode         Sales  Sub-Category
# 0     First Class  3.455723e+05          1501
# 1        Same Day  1.252190e+05           538
# 2    Second Class  4.499142e+05          1902
# 3  Standard Class  1.340831e+06          5859

# %% [markdown]
# PIVOT TABLES

# %%
pd.pivot_table(data=data,index="Ship Mode",columns="Segment",values="Sales",aggfunc="mean")
# Out:
# Segment           Consumer   Corporate  Home Office
# Ship Mode
# First Class     209.410526  219.188149   305.349843
# Same Day        184.141901  395.801079   202.191455
# Second Class    229.437224  236.070103   260.462429
# Standard Class  231.731368  225.447479   226.296486

# %%
pd.pivot_table(data=data,index=["Segment","Region"],columns="Ship Mode",values="Sales",aggfunc="mean")
# Out:
# Ship Mode            First Class    Same Day  Second Class  Standard Class
# Segment     Region
# Consumer    Central   195.445000  170.529012    179.790402      226.363633
#             East      213.252451  242.799709    217.327269      258.448591
#             South     186.504755  165.967531    282.389591      234.680287
#             West      223.621834  152.356656    244.267980      212.433398
# Corporate   Central   181.535737  133.500000    227.883209      245.537248
#             East      150.713913  433.007578    241.073520      227.627696
#             South     231.028967  660.487200    320.393009      191.592030
#             West      284.692824  341.296927    190.472270      225.731680
# Home Office Central   240.580725  189.898833    287.147436      176.378612
#             East      408.757764  128.276000    196.571877      236.451628
#             South     241.805813  156.708211    219.328175      309.170469
# ...

# %%
pd.pivot_table(data=data,index=["Segment","Region"],columns="Ship Mode",values="Sales",aggfunc="sum")
# Out:
# Ship Mode            First Class   Same Day  Second Class  Standard Class
# Segment     Region
# Consumer    Central   26971.4100  13812.850    38295.3556     171130.9064
#             East      56725.1520  20880.775    63024.9080     207275.7700
#             South     20515.5230   8132.409    49418.1785     116636.1025
#             West      53892.8620  14626.239    79387.0935     207334.9965
# Corporate   Central   18335.1094   1735.500    30308.4668     101652.4206
#             East      17332.1000  19485.341    36161.0280     122918.9560
#             South     20792.6070   9907.308    35243.2310      54603.7285
#             West      46120.2375  13993.174    37332.5650     122572.3020
# Home Office Central   12750.7784   4557.572    29001.8910      44094.6530
#             East      36379.4410   2950.348    15922.3220      70462.5850
#             South      7737.7860   2977.456     8773.1270      54414.0025
# ...

# %% [markdown]
# Time Series Functionality

# %%
pd.Timestamp("2025-9-20")
# Out:
# Timestamp('2025-09-20 00:00:00')

# %%
pd.date_range(start = pd.Timestamp("2025-9-20"),periods=5,freq='d')
# Out:
# DatetimeIndex(['2025-09-20', '2025-09-21', '2025-09-22', '2025-09-23',
#                '2025-09-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
start_date = pd.Timestamp("2025-9-20 01:20:00")

# %%
pd.date_range(start = start_date,periods=5,freq='YE')
# Out:
# DatetimeIndex(['2025-12-31 01:20:00', '2026-12-31 01:20:00',
#                '2027-12-31 01:20:00', '2028-12-31 01:20:00',
#                '2029-12-31 01:20:00'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
pd.date_range(start = start_date,periods=5,freq='ME')
# Out:
# DatetimeIndex(['2025-09-30 01:20:00', '2025-10-31 01:20:00',
#                '2025-11-30 01:20:00', '2025-12-31 01:20:00',
#                '2026-01-31 01:20:00'],
#               dtype='datetime64[ns]', freq='ME')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"],format='mixed')

# %%
data["Ship Date"] = pd.to_datetime(data["Ship Date"],format='mixed')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
import datetime as dt

# %%
# has to be a datetime column
data["Order_Month"] = data['Order Date'].dt.month

# %%
data.groupby("Order_Month")['Sales'].sum().sort_values(ascending=False)
# Out:
# Order_Month
# 11    268768.7885
# 12    246266.5152
# 9     245155.0671
# 3     212256.1344
# 8     207601.7939
# 10    183851.9562
# 5     166000.7467
# 7     159472.5865
# 1     155990.9154
# 4     142984.2481
# 6     142034.7713
# 2     131153.2594
# Name: Sales, dtype: float64

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Order_Month'],
#       dtype='object')

# %%
data['Order_Year'] = data['Order Date'].dt.year

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.groupby("Order_Year")['Sales'].sum().sort_values(ascending=False)
# Out:
# Order_Year
# 2018    722052.0192
# 2017    600192.5500
# 2015    479856.2081
# 2016    459436.0054
# Name: Sales, dtype: float64

# %%
def tax(sales):
    
    tax_value = sales * 0.15
    return tax_value

# %%
data['Sales_Tax'] = data['Sales'].apply(lambda x : x * 0.15)

# %%
data['Sales'].apply(tax)
# Out:
# 0        39.294000
# 1       109.791000
# 2         2.193000
# 3       143.636625
# 4         3.355200
#            ...
# 9795      0.569700
# 9796      1.555200
# 9797     35.278200
# 9798      3.956400
# 9799      1.557600
# Name: Sales, Length: 9800, dtype: float64

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# Resample

# %%
data['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.set_index("Order Date",inplace=True)

# %%
df.resample("QE")['Sales'].sum()
# Out:
# Order Date
# 2015-03-31     95444.4300
# 2015-06-30     83411.8406
# 2015-09-30    138500.2233
# 2015-12-31    162499.7142
# 2016-03-31     84565.4160
# 2016-06-30     97334.4352
# 2016-09-30    143003.2370
# 2016-12-31    134532.9172
# 2017-03-31    135945.9150
# 2017-06-30    144628.9808
# 2017-09-30    128221.0637
# 2017-12-31    191396.5905
# 2018-03-31    183444.5482
# 2018-06-30    125644.5095
# 2018-09-30    202504.9235
# 2018-12-31    210458.0380
# Freq: QE-DEC, Name: Sales, dtype: float64
