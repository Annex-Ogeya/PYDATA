# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\user\Desktop\New Folder 2\commodity_futures.csv")

# %%
data.head()
# Out:
#          Date  NATURAL GAS   GOLD  WTI CRUDE  BRENT CRUDE  SOYBEANS    CORN  \
# 0  2000-01-03          NaN    NaN        NaN          NaN    456.50  200.75
# 1  2000-01-04        2.176  283.7      25.55        24.39    464.25  203.00
# 2  2000-01-05        2.168  282.1      24.91        23.73    469.25  203.00
# 3  2000-01-06        2.196  282.4      24.78        23.62    468.00  203.75
# 4  2000-01-07        2.173  282.9      24.22        23.09    471.50  207.00
#
#    COPPER  SILVER  LOW SULPHUR GAS OIL  ...     ZINC  ULS DIESEL  NICKEL  \
# 0     NaN     NaN                  NaN  ...  1237.50         NaN  8446.0
# 1  0.8480   5.375               213.50  ...  1215.00       67.78  8314.0
# 2  0.8565   5.210               213.00  ...  1209.25       66.55  8307.0
# 3  0.8530   5.167               211.25  ...  1212.00       66.28  8252.0
# 4  0.8540   5.195               205.25  ...  1209.25       64.75  8174.0
#
#     WHEAT  SUGAR  GASOLINE  COFFEE  LEAN HOGS  HRW WHEAT  COTTON
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6092 entries, 0 to 6091
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6092 non-null   object
#  1   NATURAL GAS          6083 non-null   float64
#  2   GOLD                 6082 non-null   float64
#  3   WTI CRUDE            6083 non-null   float64
#  4   BRENT CRUDE          6090 non-null   float64
#  5   SOYBEANS             6083 non-null   float64
#  6   CORN                 6084 non-null   float64
#  7   COPPER               6083 non-null   float64
#  8   SILVER               6079 non-null   float64
#  9   LOW SULPHUR GAS OIL  6090 non-null   float64
#  10  LIVE CATTLE          6084 non-null   float64
#  11  SOYBEAN OIL          6079 non-null   float64
#  12  ALUMINIUM            6045 non-null   float64
#  13  SOYBEAN MEAL         6082 non-null   float64
#  14  ZINC                 6046 non-null   float64
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.10.6'

# %%
fig=plt.figure(figsize=(10,6))
plt.plot(data['Date'],data['GOLD'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=6092, step=1)

# %%
fig,ax=plt.subplots(1,2,figsize=(16,4))
ax[0].plot(data['Date'],data['GOLD'])
ax[1].plot(data['Date'],data['ALUMINIUM'])

# %%
plt.figure(figsize=(12,6))
x=data['Date']
y=data['GOLD']
z=data['ALUMINIUM']
plt.plot(x,y,label='GOLD',color='green')
plt.plot(x,z,label='ALUMINIUM')
plt.title("Gold Prices Over Time",fontdict={'fontsize':12,'fontweight':"bold"})
plt.xlabel("Date")
plt.ylabel("Commodity Price")
plt.legend
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
x=data['Date']
y=data['GOLD']
z=data['ALUMINIUM']
ax[0].plot(x,y,color='beige',label='GOLD')
ax[1].plot(x,z,color='maroon',label='ALUMINIUM')
ax[0].legend()
ax[1].legend()
ax[0].set_title("Gold Over Time")
ax[1].set_title("Aluminium Over Time")
ax[0].set_xlabel("Date")
ax[1].set_xlabel("Date")
ax[0].set_ylabel("Gold Prices")
ax[1].set_ylabel("Aluminium Prices")
plt.show()

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\New Folder 2\quantium_merged_data (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246740 entries, 0 to 246739
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        246740 non-null  int64
#  1   LYLTY_CARD_NBR    246740 non-null  int64
#  2   DATE              246740 non-null  object
#  3   STORE_NBR         246740 non-null  int64
#  4   TXN_ID            246740 non-null  int64
#  5   PROD_NBR          246740 non-null  int64
#  6   PROD_NAME         246740 non-null  object
#  7   PROD_QTY          246740 non-null  int64
#  8   TOT_SALES         246740 non-null  float64
#  9   BRAND             246740 non-null  object
#  10  PACKET_SIZE       246740 non-null  int64
#  11  LIFESTAGE         246740 non-null  object
#  12  PREMIUM_CUSTOMER  246740 non-null  object
#  13  ext_names         246740 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 26.4+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0           0            1000  2018-10-17          1       1         5
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES       BRAND  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0     Natural
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7         RRD
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6     GrnWves
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0     Natural
# 4          WW Original Stacked Chips 160g         1        1.9  Woolworths
#
#    PACKET_SIZE              LIFESTAGE PREMIUM_CUSTOMER  \
# ...

# %%
# check the number of unique brands
df["BRAND"].unique()
# Out:
# array(['Natural', 'RRD', 'GrnWves', 'Woolworths', 'Cheetos', 'Infuzions',
#        'Doritos', 'Smiths', 'Kettle', 'CCs', 'Tostitos', 'Cobs', 'Burger',
#        'Thins', 'Tyrrells', 'Cheezels', 'Twisties', 'Sunbites',
#        'Pringles', 'French'], dtype=object)

# %%
df["BRAND"].nunique()
# Out:
# 20

# %%
# what brand is contributing the most in sales
brand_sales=df.groupby("BRAND")[['TOT_SALES']].sum().reset_index().sort_values(by="TOT_SALES",ascending=False)

# %%
brand_sales
# Out:
#          BRAND  TOT_SALES
# 9       Kettle   390239.8
# 5      Doritos   226329.9
# 13      Smiths   217492.0
# 11    Pringles   177655.5
# 8    Infuzions    99047.6
# 15       Thins    88852.5
# 12         RRD    87607.5
# 17    Twisties    81522.1
# 16    Tostitos    79789.6
# 4         Cobs    70569.8
# 18    Tyrrells    51647.4
# 7      GrnWves    51617.2
# 10     Natural    42318.0
# 19  Woolworths    41059.1
# 3     Cheezels    40029.9
# 1          CCs    18078.9
# 2      Cheetos    16884.5
# 14    Sunbites     9676.4
# 6       French     7929.0
# 0       Burger     6831.0

# %%
plt.figure(figsize=(15,6))
plt.bar(brand_sales["BRAND"],brand_sales['TOT_SALES'])
plt.tick_params(axis='x',labelrotation=45)
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0           0            1000  2018-10-17          1       1         5
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES       BRAND  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0     Natural
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7         RRD
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6     GrnWves
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0     Natural
# 4          WW Original Stacked Chips 160g         1        1.9  Woolworths
#
#    PACKET_SIZE              LIFESTAGE PREMIUM_CUSTOMER  \
# ...

# %% [markdown]
# High level overview of our dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'LYLTY_CARD_NBR', 'DATE', 'STORE_NBR', 'TXN_ID',
#        'PROD_NBR', 'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'BRAND',
#        'PACKET_SIZE', 'LIFESTAGE', 'PREMIUM_CUSTOMER', 'ext_names'],
#       dtype='object')

# %%
sales=df['TOT_SALES'].sum()
print(f"The total sales amount to:{sales}")
# Out:
# The total sales amount to:1805177.7000000002

# %%
transactions=len(df)
print(f"The sales were from:{transactions}unique transactions")
# Out:
# The sales were from:246740unique transactions

# %%
unique_customer=df['LYLTY_CARD_NBR'].nunique()
print(f"We have{unique_customer}unique customer")
# Out:
# We have71287unique customer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246740 entries, 0 to 246739
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        246740 non-null  int64
#  1   LYLTY_CARD_NBR    246740 non-null  int64
#  2   DATE              246740 non-null  object
#  3   STORE_NBR         246740 non-null  int64
#  4   TXN_ID            246740 non-null  int64
#  5   PROD_NBR          246740 non-null  int64
#  6   PROD_NAME         246740 non-null  object
#  7   PROD_QTY          246740 non-null  int64
#  8   TOT_SALES         246740 non-null  float64
#  9   BRAND             246740 non-null  object
#  10  PACKET_SIZE       246740 non-null  int64
#  11  LIFESTAGE         246740 non-null  object
#  12  PREMIUM_CUSTOMER  246740 non-null  object
#  13  ext_names         246740 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 26.4+ MB

# %%
brands=df['BRAND'].nunique()
print(f"We have{brands}unique brands contributing to our sales")
# Out:
# We have20unique brands contributing to our sales

# %%
quantity=df['PROD_QTY'].sum()
print(f"We sold {quantity} chips packets across the period")
# Out:
# We sold 470399 chips packets across the period

# %%
# the evolution of sales overtime
plt.figure(figsize=(12,5))
x=df['DATE']
y=df['TOT_SALES']
plt.plot(x,y)
plt.title("Sales Over Time")
plt.show()

# %%
sales_df=df.groupby('DATE')["TOT_SALES"].sum().reset_index()
sales_df.head()
# Out:
#          DATE  TOT_SALES
# 0  2018-07-01     4920.1
# 1  2018-07-02     4877.0
# 2  2018-07-03     4954.7
# 3  2018-07-04     4968.1
# 4  2018-07-05     4682.0

# %%
plt.figure(figsize=(12,5))
x=sales_df['DATE']
y=sales_df['TOT_SALES']
plt.plot(x,y)
plt.title("Sales Over Time")
plt.show()

# %%
transactions_df=df.groupby('DATE')[["TOT_SALES"]].count().reset_index()
transactions_df.head()
# Out:
#          DATE  TOT_SALES
# 0  2018-07-01        663
# 1  2018-07-02        650
# 2  2018-07-03        674
# 3  2018-07-04        669
# 4  2018-07-05        660

# %%
plt.figure(figsize=(12,5))
x=transactions_df['DATE']
y=transactions_df['TOT_SALES']
plt.plot(x,y)
plt.title("Transactions Over Time")
plt.show()

# %%
df['PREMIUM_CUSTOMER'].nunique()
# Out:
# 3

# %%
# contribution of sales by premium_customer
cust_sales=df.groupby('PREMIUM_CUSTOMER')["TOT_SALES"].sum().reset_index()
cust_sales
# Out:
#   PREMIUM_CUSTOMER  TOT_SALES
# 0           Budget  631406.85
# 1       Mainstream  700865.40
# 2          Premium  472905.45

# %%
plt.figure(figsize=(5,5))
explode=(0.1,0.2,1)
plt.pie=(cust_sales)['TOT_SALES'],labels

# %%
# what's the distributions of our sales;histograms,KDE,box plots
plt.figure(figsize=(6,5))
plt.hist(df['TOT_SALES'])
plt.title("Sales Distribution")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,5))
sns.kdeplot(data=df,x='TOT_SALES')
plt.title("Sales Distribution")
plt.show()

# %%
# hue

# %%
#boxplots
plt.figure(figsize=(12,4))
sns.boxplot(data=df,x='TOT_SALES',hue="PREMIUM_CUSTOMER")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.violinplot(data=df,x='TOT_SALES',hue="PREMIUM_CUSTOMER")
plt.show()

# %%
# scatter plots
plt.figure(figsize=(6,5))
sns.scatterplot(data=df,x='TOT_SALES',y='PROD_QTY')
plt.show()
